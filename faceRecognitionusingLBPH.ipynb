# %%
#Code for WhatsApp, Email alert & provision of resources in AWS using Terraform


import os
import pywhatkit
import datetime

def whatsapp():
    try:
      pywhatkit.sendwhatmsg("+91XXXXXXXXXX", "Face Detection Task completed!", datetime.datetime.now().hour, datetime.datetime.now().minute + 1)
      # pywhatkit.sendwhatmsg("+91XXXXXXXXXX", "Message", time_hrs_24hr_format, time_min)
      print("Whatsapp message successfully Sent!")
      
    except:
      print("An Unexpected Error!")

def email():
    import pywhatkit as kitkat
    kitkat.send_mail('sender_email', 'password', 'Face detected', 'Samar your face detected using Python face dectector', 'samar10pratapsingh@gmail.com')
    # kitkat.send_mail('sender_email', 'sender_password', 'subject', 'body_of_email', 'receiver_email')
    
def aws():
    os.system("terraform init")
    os.system("terraform apply --auto-approve")    # running terraform code to launch resources in AWS
    print("EC2 Instance launched, EBS vol created & Vol attached to the EC2 instance in AWS...")

# %%
#Collecting Dataset of second user (here Prajwal)

import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    else:
        
        for (x,y,w,h) in faces:
            cropped_face = img[y:y+h, x:x+w]

        return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0
# Collect 200 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/prajwal/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        pass
    if cv2.waitKey(1) == 13 or count == 200: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
#Training the second model based on dataset collected (here prajwal_model)


import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/prajwal/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer

prajwal_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
prajwal_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")

# %%
#Collecting Dataset of second user (here Samar)

import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    else:
        
        for (x,y,w,h) in faces:
            cropped_face = img[y:y+h, x:x+w]

        return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0
# Collect 200 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/samar/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        pass
    if cv2.waitKey(1) == 13 or count == 200: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
#Training first model based on the Dataset collected (samar_model)

import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/samar/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer

samar_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
samar_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")

# %%
#Face Detector


# Based on the detection this automatically runs some tasks
# If User1 (here Samar) Detected then WhatsApp & Email alert will be sent
# If User2 (here Prajwal) detected then EC2 instance & EBS vol will be launched & attached in AWS

import cv2
import numpy as np
import os


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

cap = cv2.VideoCapture(0)
count1 = 0
count2 = 0
while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = samar_model.predict(face)
        results2 = prajwal_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 50:
            confidence = int( 100 * (1 - (results2[1])/400) )
            display_string = str(confidence) + '% Confident it is Samar'
            hey_string = "Hey Samar"
            
        elif results2[1] < 50:
            count2 = count2 + 1
            confidence2 = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is Prajwal'
            hey_string = "Hey Prajwal"
            if count2 == 1:
                aws()
        
        else: 
            cv2.putText(image, "I dont know u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
             if confidence > 70:
            count1 = count1 + 1
            cv2.putText(image, hey_string, (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.putText(image, display_string, (120, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            if count1 == 1:
                whatsapp()
                email()
            
            
        elif confidence2 > 70:
            count2 = count2 + 1
            cv2.putText(image, hey_string, (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.putText(image, display_string, (120, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            if count2 == 1:
                aws()
            
        else: 
            cv2.putText(image, "I dont know U :)", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            
    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
                
    if cv2.waitKey(10) == 13:
        break
cap.release()
cv2.destroyAllWindows()
